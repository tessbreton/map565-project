# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %%
data = pd.read_csv('../data/avocado.csv')
data = data.drop('Unnamed: 0',axis = 1)
data.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16  \
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df1 = data.copy(deep = True)
df1['Date'] = pd.to_datetime(df1['Date'])
df1.set_index('Date',inplace = True)
df1 = df1.resample('W').sum()
df1.head()
# Out:
#             AveragePrice  Total Volume         4046         4225        4770
# Date
# 2015-01-04        140.54  8.467434e+07  33098258.74  36851038.43  2278818.64  \
# 2015-01-11        148.03  7.855581e+07  31024164.99  32808429.84  2349167.45
# 2015-01-18        150.24  7.838878e+07  31802706.86  31662041.93  2208250.55
# 2015-01-25        150.89  7.646628e+07  32305132.87  28929122.37  2078378.86
# 2015-02-01        134.68  1.194532e+08  50292988.96  50696230.48  3687489.31
#
#              Total Bags   Small Bags  Large Bags  XLarge Bags
# Date
# 2015-01-04  12446221.39   9910008.90  2485655.90     50556.59  \
# 2015-01-11  12374044.96  10352936.42  1977832.00     43276.54
# 2015-01-18  12715784.74  10548854.11  2145586.13     21344.50
# 2015-01-25  13153646.97  10877316.95  2252815.92     23514.10
# 2015-02-01  14776526.50  11576833.65  3073989.39    125703.46
#
#                                                          type    year
# Date
# 2015-01-04  conventionalconventionalconventionalconvention...  217620  \
# 2015-01-11  conventionalconventionalconventionalconvention...  217620
# 2015-01-18  conventionalconventionalconventionalconvention...  217620
# 2015-01-25  conventionalconventionalconventionalconvention...  217620
# 2015-02-01  conventionalconventionalconventionalconvention...  217620
#
#                                                        region
# Date
# 2015-01-04  AlbanyAtlantaBaltimoreWashingtonBoiseBostonBuf...
# 2015-01-11  AlbanyAtlantaBaltimoreWashingtonBoiseBostonBuf...
# 2015-01-18  AlbanyAtlantaBaltimoreWashingtonBoiseBostonBuf...
# 2015-01-25  AlbanyAtlantaBaltimoreWashingtonBoiseBostonBuf...
# 2015-02-01  AlbanyAtlantaBaltimoreWashingtonBoiseBostonBuf...

# %%
l3 = list(df1.columns)
l3.remove('AveragePrice')

df1.drop(columns = l3,inplace =True)
df1.head()
# Out:
#             AveragePrice
# Date
# 2015-01-04        140.54
# 2015-01-11        148.03
# 2015-01-18        150.24
# 2015-01-25        150.89
# 2015-02-01        134.68
